# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv("mc_ratings.csv")

# %%
ratings
# Out:
#                      critic_url                                 movie_url  \
# 0       /critic/joe-morgenstern                        /movie/hard-powder
# 1       /critic/joe-morgenstern   /movie/the-lego-movie-2-the-second-part
# 2       /critic/joe-morgenstern                    /movie/never-look-away
# 3       /critic/joe-morgenstern                   /movie/daughter-of-mine
# 4       /critic/joe-morgenstern                             /movie/arctic
# 5       /critic/joe-morgenstern                     /movie/miss-bala-2019
# 6       /critic/joe-morgenstern                     /movie/the-invisibles
# 7       /critic/joe-morgenstern          /movie/the-kid-who-would-be-king
# 8       /critic/joe-morgenstern                              /movie/glass
# 9       /critic/joe-morgenstern                         /movie/the-upside
# 10      /critic/joe-morgenstern                         /movie/stan-ollie
# 11      /critic/joe-morgenstern                          /movie/destroyer
# 12      /critic/joe-morgenstern                /movie/on-the-basis-of-sex
# 13      /critic/joe-morgenstern                          /movie/vice-2018
# 14      /critic/joe-morgenstern                           /movie/cold-war
# 15      /critic/joe-morgenstern                  /movie/welcome-to-marwen
# 16      /critic/joe-morgenstern               /movie/mary-poppins-returns
# 17      /critic/joe-morgenstern                      /movie/the-mule-2018
# 18      /critic/joe-morgenstern   /movie/spider-man-into-the-spider-verse
# 19      /critic/joe-morgenstern         /movie/if-beale-street-could-talk
# 20      /critic/joe-morgenstern                /movie/mary-queen-of-scots
# 21      /critic/joe-morgenstern                            /movie/vox-lux
# 22      /critic/joe-morgenstern            /movie/anna-and-the-apocalypse
# 23      /critic/joe-morgenstern                              /movie/mirai
# 24      /critic/joe-morgenstern                      /movie/the-favourite
# 25      /critic/joe-morgenstern                        /movie/shoplifters
# 26      /critic/joe-morgenstern                               /movie/roma
# 27      /critic/joe-morgenstern                         /movie/green-book
# 28      /critic/joe-morgenstern                             /movie/widows
# 29      /critic/joe-morgenstern                   /movie/the-front-runner
# ...                         ...                                       ...
# 207503    /critic/linda-deutsch             /movie/the-great-muppet-caper
# 207504    /critic/linda-deutsch           /movie/the-comfort-of-strangers
# 207505    /critic/linda-deutsch                               /movie/dune
# 207506     /critic/karen-gordon                 /movie/alita-battle-angel
# 207507     /critic/karen-gordon                 /movie/victoria-and-abdul
# 207508     /critic/karen-gordon                  /movie/a-wrinkle-in-time
# 207509     /critic/karen-gordon                /movie/the-old-man-the-gun
# 207510     /critic/karen-gordon               /movie/mary-poppins-returns
# 207511     /critic/karen-gordon                             /movie/border
# 207512     /critic/karen-gordon  /movie/dead-in-a-week-or-your-money-back
# 207513     /critic/karen-gordon                             /movie/widows
# 207514     /critic/karen-gordon                         /movie/boy-erased
# 207515     /critic/karen-gordon               /movie/the-sisters-brothers
# 207516     /critic/karen-gordon                     /movie/a-star-is-born
# 207517     /critic/karen-gordon                    /movie/kusama-infinity
# 207518     /critic/karen-gordon                       /movie/juliet-naked
# 207519     /critic/karen-gordon                       /movie/eighth-grade
# 207520     /critic/jeff-shannon                               /movie/dave
# 207521     /critic/jeff-shannon                        /movie/love-affair
# 207522     /critic/jeff-shannon                             /movie/junior
# 207523     /critic/jeff-shannon       /movie/hellraiser-iii-hell-on-earth
# 207524     /critic/jeff-shannon                             /movie/sliver
# 207525     /critic/jeff-shannon            /movie/the-beverly-hillbillies
# 207526     /critic/jeff-shannon                      /movie/the-vanishing
# 207527     /critic/jeff-shannon                  /movie/the-secret-garden
# 207528     /critic/jeff-shannon          /movie/wes-cravens-new-nightmare
# 207529     /critic/jeff-shannon                     /movie/waynes-world-2
# 207530     /critic/jeff-shannon             /movie/angels-in-the-outfield
# 207531        /critic/ryan-swen             /movie/notes-on-an-appearance
# 207532        /critic/ryan-swen                  /movie/crazy-rich-asians
#
#         rating
# 0           30
# 1           80
# 2           90
# 3           90
# 4           70
# 5           20
# 6           70
# 7           50
# 8           40
# 9           40
# 10          80
# 11          50
# 12          40
# 13          50
# 14         100
# 15           0
# 16          40
# 17          50
# 18         100
# 19          80
# 20          50
# 21          40
# 22          40
# 23          80
# 24          90
# 25         100
# 26         100
# 27          40
# 28          90
# 29          50
# ...        ...
# 207503     100
# 207504      75
# 207505      50
# 207506      58
# 207507      75
# 207508      91
# 207509      91
# 207510     100
# 207511      83
# 207512      42
# 207513      83
# 207514      75
# 207515     100
# 207516      75
# 207517      75
# 207518      91
# 207519     100
# 207520     100
# 207521      75
# 207522      75
# 207523      63
# 207524      50
# 207525      63
# 207526      50
# 207527      88
# 207528      75
# 207529      63
# 207530      50
# 207531      83
# 207532      33
#
# [207533 rows x 3 columns]

# %%
def create_ratings_map(ratings, movie_key, rating_key):
    avg_ratings_map = dict.fromkeys(ratings[movie_key].values, (0, 0))
    for review in ratings.iterrows():
        movie_name = review[1][movie_key]
        movie_rating = review[1][rating_key]
        old_value = avg_ratings_map[movie_name]
        new_value = (old_value[0] + 1, old_value[1] + int(movie_rating))
        avg_ratings_map[movie_name] = new_value
    for movie in avg_ratings_map:
        avg_ratings_map[movie] = avg_ratings_map[movie][1] / avg_ratings_map[movie][0]
        
    return avg_ratings_map

# %%
def calculate_rmse(ratings, avg_ratings_map, movie_key, ratings_key, num_entries):
    error = 0
    for review in ratings.iterrows():
        movie_name = review[1][movie_key]
        movie_rating = review[1][ratings_key]
        diff = float(movie_rating) - avg_ratings_map[movie_name]
        error += diff ** 2
    mean = error / num_entries
    rmse = mean ** 0.5
    return rmse

# %%
from fastai.collab import *

# %%
path = untar_data(URLs.ML_SAMPLE)
movielens_ratings = pd.read_csv(path/'ratings.csv')

# %%
avg_ratings_map = create_ratings_map(movielens_ratings, 'movieId', 'rating')

# %%
rmse = calculate_rmse(movielens_ratings, avg_ratings_map, 'movieId', 'rating', 6031)
print(rmse)
# Out:
# 0.8812529892360426

# %%
binary_ratings = [1 if rating >= 50 else 0 for rating in ratings['rating'].values]
ratings['binary_ratings'] = pd.DataFrame(binary_ratings)

# 207522     /critic/jeff-shannon                             /movie/junior
# 207523     /critic/jeff-shannon       /movie/hellraiser-iii-hell-on-earth
# 207524     /critic/jeff-shannon                             /movie/sliver
# 207525     /critic/jeff-shannon            /movie/the-beverly-hillbillies
# 207526     /critic/jeff-shannon                      /movie/the-vanishing
# 207527     /critic/jeff-shannon                  /movie/the-secret-garden
# 207528     /critic/jeff-shannon          /movie/wes-cravens-new-nightmare
# 207529     /critic/jeff-shannon                     /movie/waynes-world-2
# 207530     /critic/jeff-shannon             /movie/angels-in-the-outfield
# 207531        /critic/ryan-swen             /movie/notes-on-an-appearance
# 207532        /critic/ryan-swen                  /movie/crazy-rich-asians
#
#         rating  binary_ratings
# 0           30               0
# 1           80               1
# 2           90               1
# 3           90               1
# 4           70               1
# 5           20               0
# 6           70               1
# 7           50               1
# 8           40               0
# 9           40               0
# 10          80               1
# 11          50               1
# 12          40               0
# 13          50               1
# 14         100               1
# 15           0               0
# 16          40               0
# 17          50               1
# 18         100               1
# 19          80               1
# 20          50               1
# 21          40               0
# 22          40               0
# 23          80               1
# 24          90               1
# 25         100               1
# 26         100               1
# 27          40               0
# 28          90               1
# 29          50               1
# ...        ...             ...
# 207503     100               1
# 207504      75               1
# 207505      50               1
# 207506      58               1
# 207507      75               1
# 207508      91               1
# 207509      91               1
# 207510     100               1
# 207511      83               1
# 207512      42               0
# 207513      83               1
# 207514      75               1
# 207515     100               1
# 207516      75               1
# 207517      75               1
# 207518      91               1
# 207519     100               1
# 207520     100               1
# 207521      75               1
# 207522      75               1
# 207523      63               1
# 207524      50               1
# 207525      63               1
# 207526      50               1
# 207527      88               1
# 207528      75               1
# 207529      63               1
# 207530      50               1
# 207531      83               1
# 207532      33               0
#
# [207533 rows x 4 columns]

# %%
avg_ratings_map = create_ratings_map(ratings, 'movie_url', 'binary_ratings')
rmse = calculate_rmse(ratings, avg_ratings_map, 'movie_url', 'binary_ratings', 207533)
print(rmse)
# Out:
# 0.3222504971139414

# %%
# !ls
# Out:
# Untitled.ipynb mc_critics.csv mc_ratings.csv

# %%
rt_reviews = pd.read_csv("../Rotten Tomatoes/reviews.csv")

# %%
rt_binary_ratings = [1 if rating == "fresh" else 0 for rating in rt_reviews['rt_score'].values]
rt_reviews['binary_ratings'] = pd.DataFrame(rt_binary_ratings)

# %%
avg_ratings_map = create_ratings_map(rt_reviews, 'movie_id', 'binary_ratings')
rmse = calculate_rmse(rt_reviews, avg_ratings_map, 'movie_id', 'binary_ratings', 658482)
print(rmse)
# Out:
# 0.3870559372913993

# %%
from sklearn.metrics import *

# %%
preds = [avg_ratings_map[movie_name] for movie_name in rt_reviews['movie_id'].values]

# %%
preds = [1 if val >= 0.5 else 0 for val in preds]

# %%
print(f1_score(rt_reviews['binary_ratings'].values, preds))
# Out:
# 0.8377027781710198

# %%
print (accuracy_score(rt_reviews['binary_ratings'].values, preds))
# Out:
# 0.778889931691375
